# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("dating-binned.csv")

# %%
test_data = data.sample(frac = 0.2, random_state=47)
training_data = data.drop(test_data.index)

# %%
test_data.head()
# Out:
#       gender             age           age_o  race  race_o  samerace  \
# 529        0  (17.999, 26.0]  (17.999, 26.0]     3       2         0
# 4218       0    (26.0, 34.0]    (26.0, 34.0]     2       2         1
# 3474       1    (26.0, 34.0]    (26.0, 34.0]     0       2         0
# 185        0  (17.999, 26.0]    (26.0, 34.0]     2       2         1
# 3889       1    (26.0, 34.0]    (26.0, 34.0]     2       0         0
#
#      importance_same_race importance_same_religion  field pref_o_attractive  \
# 529         (-0.001, 2.0]            (-0.001, 2.0]    121        (0.2, 0.4]
# 4218          (8.0, 10.0]               (4.0, 6.0]      7        (0.2, 0.4]
# 3474        (-0.001, 2.0]            (-0.001, 2.0]     69        (0.2, 0.4]
# 185            (2.0, 4.0]               (4.0, 6.0]    192        (0.2, 0.4]
# 3889        (-0.001, 2.0]               (2.0, 4.0]     23     (-0.001, 0.2]
#
#       ...        theater       movies     concerts        music  \
# 529   ...  (-0.001, 2.0]  (8.0, 10.0]   (6.0, 8.0]  (8.0, 10.0]
# 4218  ...    (8.0, 10.0]  (8.0, 10.0]  (8.0, 10.0]  (8.0, 10.0]
# 3474  ...     (4.0, 6.0]   (2.0, 4.0]   (2.0, 4.0]   (6.0, 8.0]
# 185   ...     (4.0, 6.0]   (6.0, 8.0]   (4.0, 6.0]   (6.0, 8.0]
# 3889  ...  (-0.001, 2.0]   (6.0, 8.0]   (6.0, 8.0]  (8.0, 10.0]
#
#            shopping           yoga interests_correlate  \
# 529     (8.0, 10.0]  (-0.001, 2.0]          (0.2, 0.6]
# 4218     (4.0, 6.0]     (6.0, 8.0]        (-0.6, -0.2]
# 3474  (-0.001, 2.0]     (6.0, 8.0]         (-0.2, 0.2]
# 185     (8.0, 10.0]     (4.0, 6.0]         (-0.2, 0.2]
# 3889     (4.0, 6.0]  (-0.001, 2.0]          (0.2, 0.6]
#
#      expected_happy_with_sd_people         like decision
# 529                     (4.0, 6.0]   (6.0, 8.0]        1
# 4218                    (4.0, 6.0]   (4.0, 6.0]        0
# 3474                    (4.0, 6.0]  (8.0, 10.0]        1
# 185                     (6.0, 8.0]   (4.0, 6.0]        1
# 3889                    (4.0, 6.0]   (6.0, 8.0]        0
#
# [5 rows x 53 columns]
